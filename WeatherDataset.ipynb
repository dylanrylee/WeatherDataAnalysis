# %% [markdown]
# ### Printing The Weather Data Set

# %%
import pandas as pd
weather_data = pd.read_csv(r"C:\Users\dylan\OneDrive\Desktop\Weather Data Analysis Project\file.csv")
# This data is from https://datasciencelovers.graphy.com/products/Dataset--Project-1---Weather-Data-Analysis-64d48ec74065076bdfbcc4db?dgps_u=l&dgps_s=ucpd&dgps_t=cp_u&dgps_u_st=p&dgps_uid=664d3db10a1512061b3108e7

# %% [markdown]
# ### Importing Pandas and reading the CSV file

# %%
weather_data
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %% [markdown]
# ### Printing the Columns to see what kind of data we are dealing with

# %%
weather_data.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %% [markdown]
# ### Printing the Unique types of weather that we have in the CSV file

# %%
for i in weather_data['Weather'].unique():
    print(f'{i}\n')
# Out:
# Fog
#
# Freezing Drizzle,Fog
#
# Mostly Cloudy
#
# Cloudy
#
# Rain
#
# Rain Showers
#
# Mainly Clear
#
# Snow Showers
#
# Snow
#
# Clear
#
# Freezing Rain,Fog
#
# Freezing Rain
#
# Freezing Drizzle
#
# Rain,Snow
#
# Moderate Snow
#
# Freezing Drizzle,Snow
#
# Freezing Rain,Snow Grains
#
# Snow,Blowing Snow
#
# Freezing Fog
#
# Haze
#
# Rain,Fog
#
# Drizzle,Fog
#
# Drizzle
#
# Freezing Drizzle,Haze
#
# Freezing Rain,Haze
#
# Snow,Haze
#
# Snow,Fog
#
# Snow,Ice Pellets
#
# Rain,Haze
#
# Thunderstorms,Rain
#
# Thunderstorms,Rain Showers
#
# Thunderstorms,Heavy Rain Showers
#
# Thunderstorms,Rain Showers,Fog
#
# Thunderstorms
#
# Thunderstorms,Rain,Fog
#
# Thunderstorms,Moderate Rain Showers,Fog
#
# Rain Showers,Fog
#
# Rain Showers,Snow Showers
#
# Snow Pellets
#
# Rain,Snow,Fog
#
# Moderate Rain,Fog
#
# Freezing Rain,Ice Pellets,Fog
#
# Drizzle,Ice Pellets,Fog
#
# Drizzle,Snow
#
# Rain,Ice Pellets
#
# Drizzle,Snow,Fog
#
# Rain,Snow Grains
#
# Rain,Snow,Ice Pellets
#
# Snow Showers,Fog
# ...

# %% [markdown]
# ### Printing which types of weather condition is more popular, from highest to lowest

# %%
weather_data['Weather'].value_counts()
# Out:
# Weather
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %% [markdown]
# ### Renaming the 'Weather' Column to a more accurate name

# %%
weather_data.rename(columns= {'Weather' : 'Weather Condition'}, inplace=True)
weather_data
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %% [markdown]
# ### Printing only the data when the weather was clear

# %%
print(weather_data.groupby('Weather Condition').get_group('Clear'))
print(weather_data.groupby('Weather Condition').get_group('Mainly Clear'))
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
# ...

# %% [markdown]
# ### Total number of times the weather was Clear or Mainly Clear

# %%
len_clear = len(weather_data.groupby('Weather Condition').get_group('Clear'))
len_mainlyclear = len(weather_data.groupby('Weather Condition').get_group('Mainly Clear'))
print(f'Number of times that the weather was clear or mainly clear: {len_clear + len_mainlyclear}')
# Out:
# Number of times that the weather was clear or mainly clear: 3432

# %% [markdown]
# ### Calculating the Expected/Mean, Variance, and Standard Deviation values of the wind speed in km/h throughout the data set

# %%
weather_data.rename(columns= {'Wind Speed_km/h' : 'WindSpeed'}, inplace=True)
print("Wind Speed (km/h) Expectation, Variance, and Standard Deviation")
print(f'Expected Value: {weather_data.WindSpeed.mean()}')
print(f'Variance Value: {weather_data.WindSpeed.var()}')
print(f'Standard Deviation Value: {weather_data.WindSpeed.std()}')
# Out:
# Wind Speed (km/h) Expectation, Variance, and Standard Deviation
# Expected Value: 14.94546903460838
# Variance Value: 75.49343956137737
# Standard Deviation Value: 8.688696079468851

# %% [markdown]
# ### Calculating the Expected/Mean, Variance, and Standard Deviation values of the Relative Humidity throughout the data set

# %%
weather_data.rename(columns= {'Rel Hum_%' : 'RelativeHumidity'}, inplace=True)
print("Relative Humidity Percentage Expectation, Variance, and Standard Deviation")
print(f'Expected Value: {weather_data.RelativeHumidity.mean()}')
print(f'Variance Value: {weather_data.RelativeHumidity.var()}')
print(f'Standard Deviation Value: {weather_data.RelativeHumidity.std()}')
# Out:
# Relative Humidity Percentage Expectation, Variance, and Standard Deviation
# Expected Value: 67.43169398907104
# Variance Value: 286.24855019850196
# Standard Deviation Value: 16.91888147007662

# %% [markdown]
# ### Calculating the Expected/Mean, Variance, and Standard Deviation values of the Tempearature throughout the data set

# %%
weather_data.rename(columns= {'Temp_C' : 'Temperature'}, inplace=True)
print("Temperature Expectation, Variance, and Standard Deviation")
print(f'Expected Value: {weather_data.Temperature.mean()}')
print(f'Variance Value: {weather_data.Temperature.var()}')
print(f'Standard Deviation Value: {weather_data.Temperature.std()}')
# Out:
# Temperature Expectation, Variance, and Standard Deviation
# Expected Value: 8.798144353369764
# Variance Value: 136.6066036380462
# Standard Deviation Value: 11.687882769691276

# %% [markdown]
# ### Printing all the instances when wind speed was above 27km/h, and Temperature was higher than the Expected Value, when the Weather Condition was rainy, and then calculating the variance of the Weather Visibility

# %%
weather_data.rename(columns= {'Visibility_km' : 'WeatherVisibility'}, inplace=True)
data = weather_data[(weather_data['WindSpeed'] > 27) & (weather_data['Temperature'] > weather_data.Temperature.mean()) & (weather_data['Weather Condition'].str.contains('Rain'))]
print(data)
print(f'\n\nVariation Value of Weather Visibility from the data above: {data.WeatherVisibility.var()}\n\n')
# Out:
#              Date/Time  Temperature  Dew Point Temp_C  RelativeHumidity  \
# 1623    3/8/2012 15:00         11.7               6.6                71
# 1624    3/8/2012 16:00         11.6               6.4                70
# 1625    3/8/2012 17:00         11.3               6.9                74
# 1626    3/8/2012 18:00         10.5               7.8                83
# 2441   4/11/2012 17:00          9.3               1.3                57
# 3081     5/8/2012 9:00         11.1               9.1                87
# 3580    5/29/2012 4:00         11.4               7.0                74
# 3594   5/29/2012 18:00         20.4              17.6                84
# 3727     6/4/2012 7:00         11.7               7.9                77
# 3729     6/4/2012 9:00         11.6               7.7                77
# 4914   7/23/2012 18:00         20.6              19.1                91
# 5108   7/31/2012 20:00         22.4              18.7                80
# ...
